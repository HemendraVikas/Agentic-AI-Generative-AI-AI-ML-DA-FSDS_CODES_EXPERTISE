# %% [markdown]
# ## using python as a calculator

# %% [markdown]
# ## number

# %%
2+2
# Out:
# 4

# %%
50 - 5*6
# Out:
# 20

# %%
(50 - 5*6) / 4
# Out:
# 5.0

# %%
8 / 5  # division always returs to a floating-point number
# Out:
# 1.6

# %%
17 / 3  # classic division reutns to float
# Out:
# 5.666666666666667

# %%
17 // 3  #floor division discards the fractional part
# Out:
# 5

# %%
17 % 3   # the % operator returns the remainder of the division
# Out:
# 2

# %%
5 * 3 + 2  # floored quotient * divisor + remainder
# Out:
# 17

# %%
5 ** 2  #5 squared
# Out:
# 25

# %%
2 ** 7 # 2 to the power 7
# Out:
# 128

# %%
width = 20 
height =5 * 9
width * height
# Out:
# 900

# %%
4 * 3.75 - 1
# Out:
# 14.0

# %%
tax = 12.5 / 100
price = 100.50
price * tax
# Out:
# 12.5625

# %%
price + _
# Out:
# 113.0625

# %%
round(_, 2)
# Out:
# 113.06

# %% [markdown]
# ## text

# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
"Paris rabbit got your back :)! yay!"
# Out:
# 'Paris rabbit got your back :)! yay!'

# %%
'1995'
# Out:
# '1995'

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"doesn't"
# Out:
# "doesn't"

# %%
'"Yes," they said.'
# Out:
# '"Yes," they said.'

# %%
"\"Yes,\" they said."
# Out:
# '"Yes," they said.'

# %%
'"Isn\t," they said.'
# Out:
# '"Isn\t," they said.'

# %%
s = 'First line. \nSecond line.'
s
# Out:
# 'First line. \nSecond line.'

# %%
print(s)
# Out:
# First line.
# Second line.

# %%
print('C:\some\ name')
# Out:
# C:\some\ name

# %%
print(r'C:\some\name')
# Out:
# C:\some\name

# %%
print("""\
      Usage: thingy [OPTIONS]
      -h                     Display this usage message
      -H                     Hostname to connect to
      """)
# Out:
#       Usage: thingy [OPTIONS]
#       -h                     Display this usage message
#       -H                     Hostname to connect to

# %%
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
'Py' 'thon'
# Out:
# 'Python'

# %%
text = ('Put several string within parentheses'
        'to have them joinned together.')

# %%
text
# Out:
# 'Put several string within parenthesesto have them joinned together.'

# %%
prefix = 'Py'
result = prefix + 'thon'
print(result)   # Python
# Out:
# Python

# %%
prefix+'thon'
# Out:
# 'Python'

# %%
word = 'python'

# %%
word[0]
# Out:
# 'p'

# %%
word[5]
# Out:
# 'n'

# %%
word[-1]
# Out:
# 'n'

# %%
word[-2]
# Out:
# 'o'

# %%
word[-6]
# Out:
# 'p'

# %%
word[0:2]
# Out:
# 'py'

# %%
word[2:5]
# Out:
# 'tho'

# %%
word[:2]
# Out:
# 'py'

# %%
word[4:]
# Out:
# 'on'

# %%
word[-2:]
# Out:
# 'on'

# %%
word[:2] + word[2:]
# Out:
# 'python'

# %%
word[:4] + word[4:]
# Out:
# 'python'

# %%
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 word[42]
#
# IndexError: string index out of range

# %%
word[4:42]
# Out:
# 'on'

# %%
word[42:]
# Out:
# ''

# %%
word[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 word[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
'J' + word[1:]
# Out:
# 'Jython'

# %%
word[:2] + 'py'
# Out:
# 'pypy'

# %%
s = 'supercalifragilisticexpialidocious'

# %%
len(s)
# Out:
# 34

# %%
squares = [1, 4, 9, 16, 25]

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[0]
# Out:
# 1

# %%
squares[-1]
# Out:
# 25

# %%
squares[-3:]
# Out:
# [9, 16, 25]

# %%
squares + [36, 49, 64, 81, 100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
cubes = [1, 8, 27, 65, 125]
4 ** 3
# Out:
# 64

# %%
cubes[3] = 64

# %%
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
cubes.append(216)
cubes.append(7 ** 3)
cubes
# Out:
# [1, 8, 27, 64, 125, 216, 343]

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
id(rgb) == id(rgba)
# Out:
# True

# %%
rgba.append("Alph")
rgb
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
correct_rgba = rgba[:]
correct_rgba[-1] = "Alpha"
correct_rgba
# Out:
# ['Red', 'Green', 'Blue', 'Alpha']

# %%
rgba
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
letters = ['a','b','c','d','e','f','g']
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letters[2:5] = ['C', 'D', 'E']
letters
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']

# %%
letters[2:5] = []
letters
# Out:
# ['a', 'b', 'f', 'g']

# %%
letters[:] = []
letters
# Out:
# []

# %%
letters = ['a', 'b', 'c', 'd']
len(letters)
# Out:
# 4

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[0][1]
# Out:
# 'b'

# %%
a, b = 0, 1
while a < 10:
    print(a)
    a, b = b, a+b
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
i = 256*256
print('The value of i is', i)
# Out:
# The value of i is 65536

# %%
a,b = 0, 1
while a < 1000:
    print(a, end=',')
