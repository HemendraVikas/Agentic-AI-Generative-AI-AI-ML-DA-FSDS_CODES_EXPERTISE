# %% [markdown]
# # Variables in Python

# %%
first_name = 'HEMENDRA'

# %%
last_name = 'VIKAS'

# %%
country = 'HYD'

# %%
city = 'TELENGANA'

# %%
age = 40087

# %%
is_married = False

# %%
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']

# %%
person_info = {
    'firstname':'Asabeneh', 
    'lastname':'Yetayeh', 
    'country':'Finland',
    'city':'Helsinki'
    }

# %% [markdown]
# # Printing the values stored in the variables

# %%
print('First name:', first_name)
# Out:
# First name: HEMENDRA

# %%
print('First name length:', len(first_name))
# Out:
# First name length: 8

# %%
print('Last name: ', last_name)
# Out:
# Last name:  VIKAS

# %%
print('Last name length: ', len(last_name))
# Out:
# Last name length:  5

# %%
print('Country: ', country)
# Out:
# Country:  HYD

# %%
print('City: ', city)
# Out:
# City:  TELENGANA

# %%
print('Married: ', is_married)
# Out:
# Married:  False

# %%
print('Skills: ', skills)
# Out:
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']

# %%
print('Person information: ', person_info)
# Out:
# Person information:  {'firstname': 'Asabeneh', 'lastname': 'Yetayeh', 'country': 'Finland', 'city': 'Helsinki'}

# %% [markdown]
# # Declaring multiple variables in one line

# %%
first_name, last_name, country, age, is_married = 'Hemendra', 'Vikas', 'Helsink', 250, False

# %%
print(first_name, last_name, country, age, is_married)
# Out:
# Hemendra Vikas Helsink 250 False

# %%
print('First name:', first_name)
# Out:
# First name: Hemendra

# %%
print('Last name: ', last_name)
# Out:
# Last name:  Vikas

# %%
print('Country: ', country)
# Out:
# Country:  Helsink

# %%
print('Age: ', age)
# Out:
# Age:  250

# %%
print('Married: ', is_married)
# Out:
# Married:  False
