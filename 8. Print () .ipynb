# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1+num2
print(add)
# Out:
# 50

# %% [markdown]
# ## print result with string

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('the additon of',num1,'add',num2,'is',add)
# Out:
# the additon of 20 add 30 is 50

# %%
name = 'Python'
age = 20
city = 'hyd'

# %%
print('My name is',name,'and i am',age,'years old from',city)
# Out:
# My name is Python and i am 20 years old from hyd

# %% [markdown]
# ## print format method

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('The addition of {} and {} is={}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is=50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print('hello my name is {}, and i am {} years old  from{}'.format(name,age,city))
# Out:
# hello my name is python, and i am 20 years old  fromhyd

# %%
num1 = 100
num2 = 25
num3 = 333
avg = (num1+num2+num3)/3
avg1 = round((num1+num2+num3)/3,2)

print('the average of {}, {}, and is= {} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# the average of 100, 25, and is= 333 or 152.66666666666666

# %%
round(avg,2)
# Out:
# 152.67

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(f'the addition of {num1} and {num2} is= {add}')
# Out:
# the addition of 20 and 30 is= 50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print(f'hello my name is {name}, and i am {age} year old, from{city}.')
# Out:
# hello my name is python, and i am 20 year old, fromhyd.

# %%
num1 = 100
num2 = 25
num3 = 333
avg = round((num1+num2+num3)/3,2)

# %%
print(f'the average of {num1}, {num2} and {num3} is= {avg}')
# Out:
# the average of 100, 25 and 333 is= 152.67

# %%
num1 = 10
num2 = 20
add = num1 + num2

print('the addition of',num1,'and',num2,'is=',add)

print('the addition of {} and {} is={}'.format(num1,num2,add))

print(f'the addition of {num1} and {num2} is={add}')
# Out:
# the addition of 10 and 20 is= 30
# the addition of 10 and 20 is=30
# the addition of 10 and 20 is=30

# %% [markdown]
# ## end statement

# %%
print('hello', end= ' ')
print('world good day')
# Out:
# hello world good day

# %% [markdown]
# ## separator

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end=' ') 
print(3,'.',sep='')
# Out:
# 1 2 3.
