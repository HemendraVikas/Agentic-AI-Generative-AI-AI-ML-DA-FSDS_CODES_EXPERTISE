# %%
print(3 + 2)  # addition(+)
# Out:
# 5

# %%
print(3 - 2)   # subtraction(-)
# Out:
# 1

# %%
print(3 * 2)   # multiplication(*)
# Out:
# 6

# %%
print(3 / 2)   #division(/)
# Out:
# 1.5

# %%
print(3 ** 2)   #exponential(**)
# Out:
# 9

# %%
print(3 % 2)   #modulus(%)
# Out:
# 1

# %%
print(3 // 2)   #floor division operator
# Out:
# 1

# %% [markdown]
# ## checking datatypes

# %%
print(type(10))  # int
# Out:
# <class 'int'>

# %%
print(type(3.14))  # float
# Out:
# <class 'float'>

# %%
print(type(1+2j))  #complex
# Out:
# <class 'complex'>

# %%
print(type('HemendraVikas'))  # string
# Out:
# <class 'str'>

# %%
print(type([1, 2, 3]))   # list
# Out:
# <class 'list'>

# %%
print(type({'name':'hemendra'}))    # dictionary
# Out:
# <class 'dict'>

# %%
print(type({9.8, 3.14, 2.77}))  #set
# Out:
# <class 'set'>

# %%
print(type((9.8, 3.14, 2.7)))   # tuple
# Out:
# <class 'tuple'>

# %%
print(type(3 == 3))  # bool
# Out:
# <class 'bool'>

# %%
print(type(3 >= 3))  # bool
# Out:
# <class 'bool'>
