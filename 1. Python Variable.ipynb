# %% [markdown]
# ## variable_name = value

# %%
age = 25
print(age)
# Out:
# 25

# %%
name = "Alice"
print(name)
# Out:
# Alice

# %%
price = 19.99
print(price)
# Out:
# 19.99

# %%
is_active = True
print(is_active)
# Out:
# True

# %%
x = 10  # storing and printing a value
print(x)
# Out:
# 10

# %%
a = 5   # using variable in expessions
b = 3
result = a + b
print(result)
# Out:
# 8

# %%
score = 50   # intial value 
print(score)
# Out:
# 50

# %%
score = 100   # changing the value of 'score'
print(score)
# Out:
# 100

# %%
first_name = "john"   # assigning values to variables
last_name = "doe"

full_name = first_name + " " + last_name   # concatenating string and storing in a new variable
print(full_name)
# Out:
# john doe

# %%
length = 10  # assigning values to variables
width = 5

area = length * width   #calculating the area of a rectangle
print(area)
# Out:
# 50

# %%
x = 10   #intial value of x 
print(x)
# Out:
# 10

# %%
x = 20   # reassigning the value of x
print(x)
# Out:
# 20
